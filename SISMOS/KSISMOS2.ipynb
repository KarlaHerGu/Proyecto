# %% [markdown]
# ## Datos de Verano

# %%
from obspy import read

# %%
ls
# Out:
# AE1COMPARACIÓN.SAC         Sismo1Z.SAC
# AE1SISMO.SAC               Sismo2E.SAC
# AN1SISMO.SAC               Sismo2N.SAC
# AZ1SISMO.SAC               Sismo2Z.SAC
# E1COMPARACIÓN.SAC          ST03L173.SV.EHE..20160426_110000.mseed
# E1SISMO.SAC                ST03L173.SV.EHE..20160426_120000.mseed
# Juliaexpress.ipynb         ST03L173.SV.EHE..20160426_130000.mseed
# KSISMOS1.ipynb             ST03L173.SV.EHN..20160426_110000.mseed
# KSISMOS2.ipynb             ST03L173.SV.EHN..20160426_120000.mseed
# N1SISMO.SAC                ST03L173.SV.EHN..20160426_130000.mseed
# PrimerEvento.ipynb         ST03L173.SV.EHZ..20160426_110000.mseed
# Proyecto.ipynb             ST03L173.SV.EHZ..20160426_120000.mseed
# Py señales.ipynb           ST03L173.SV.EHZ..20160426_130000.mseed
# README.md                  SV.ST03L..EHE.SAC
# ResumenJuliacon2017.ipynb  SV.ST03L..EHN.SAC
# SegundoEvento.ipynb        SV.ST03L..EHZ.SAC
# SeñalesPy.ipynb            Untitled.ipynb
# ...

# %% [markdown]
# ### Traza Este (E)

# %%
stE2= read ("ST03L173.SV.EHE*.mseed")

# %%
stE2
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHE | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHE | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHE | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
stE2.plot()

# %%
stE2
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHE | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHE | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHE | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
trE2=stE2[0].copy()

# %%
trE2
# Out:
# SV.ST03L..EHE | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
trE2.plot()

# %%
trE2.stats
# Out:
#          network: SV
#          station: ST03L
#         location:
#          channel: EHE
#        starttime: 2016-04-26T11:00:00.000000Z
#          endtime: 2016-04-26T11:59:59.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 360000
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'record_length': 512, 'encoding': u'STEIM1', 'filesize': 485376, u'dataquality': u'D', 'number_of_records': 948, 'byteorder': u'>'})

# %%
tE2=trE2.stats.starttime

# %%
tE2
# Out:
# 2016-04-26T11:00:00.000000Z

# %%
trE2.trim(tE2+(0*60),tE2+(4*60))
# Out:
# SV.ST03L..EHE | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:04:00.000000Z | 100.0 Hz, 24001 samples

# %%
trE2.plot()

# %%
trE2.write("AE2SISMO.SAC",format="SAC")

# %%
ls
# Out:
# AE1COMPARACIÓN.SAC         Sismo1N.SAC
# AE1SISMO.SAC               Sismo1Z.SAC
# AE2SISMO.SAC               Sismo2E.SAC
# AN1SISMO.SAC               Sismo2N.SAC
# AZ1SISMO.SAC               Sismo2Z.SAC
# E1COMPARACIÓN.SAC          ST03L173.SV.EHE..20160426_110000.mseed
# E1SISMO.SAC                ST03L173.SV.EHE..20160426_120000.mseed
# Juliaexpress.ipynb         ST03L173.SV.EHE..20160426_130000.mseed
# KSISMOS1.ipynb             ST03L173.SV.EHN..20160426_110000.mseed
# KSISMOS2.ipynb             ST03L173.SV.EHN..20160426_120000.mseed
# N1SISMO.SAC                ST03L173.SV.EHN..20160426_130000.mseed
# PrimerEvento.ipynb         ST03L173.SV.EHZ..20160426_110000.mseed
# Proyecto.ipynb             ST03L173.SV.EHZ..20160426_120000.mseed
# Py señales.ipynb           ST03L173.SV.EHZ..20160426_130000.mseed
# README.md                  SV.ST03L..EHE.SAC
# ResumenJuliacon2017.ipynb  SV.ST03L..EHN.SAC
# SegundoEvento.ipynb        SV.ST03L..EHZ.SAC
# ...

# %% [markdown]
# ### Traza Norte (N)

# %%
stN2=read("ST03L173.SV.EHN*mseed")

# %%
stN2
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHN | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHN | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHN | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
stN2.plot()

# %%
stN2
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHN | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHN | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHN | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
trN2=stN2[0].copy()

# %%
trN2
# Out:
# SV.ST03L..EHN | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
trN2.plot()

# %%
trN2.stats
# Out:
#          network: SV
#          station: ST03L
#         location:
#          channel: EHN
#        starttime: 2016-04-26T11:00:00.000000Z
#          endtime: 2016-04-26T11:59:59.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 360000
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'record_length': 512, 'encoding': u'STEIM1', 'filesize': 491008, u'dataquality': u'D', 'number_of_records': 959, 'byteorder': u'>'})

# %%
tN2=trN2.stats.starttime

# %%
tN2
# Out:
# 2016-04-26T11:00:00.000000Z

# %%
trN2.trim(tN2+(0*60),tN2+(4*60))
# Out:
# SV.ST03L..EHN | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:04:00.000000Z | 100.0 Hz, 24001 samples

# %%
trN2.plot()

# %%
trN2.write("AN2SISMO.SAC",format="SAC")

# %%
ls
# Out:
# AE1COMPARACIÓN.SAC         Sismo1N.SAC
# AE1SISMO.SAC               Sismo1Z.SAC
# AE2SISMO.SAC               Sismo2E.SAC
# AN1SISMO.SAC               Sismo2N.SAC
# AN2SISMO.SAC               Sismo2Z.SAC
# AZ1SISMO.SAC               ST03L173.SV.EHE..20160426_110000.mseed
# E1COMPARACIÓN.SAC          ST03L173.SV.EHE..20160426_120000.mseed
# E1SISMO.SAC                ST03L173.SV.EHE..20160426_130000.mseed
# Juliaexpress.ipynb         ST03L173.SV.EHN..20160426_110000.mseed
# KSISMOS1.ipynb             ST03L173.SV.EHN..20160426_120000.mseed
# KSISMOS2.ipynb             ST03L173.SV.EHN..20160426_130000.mseed
# N1SISMO.SAC                ST03L173.SV.EHZ..20160426_110000.mseed
# PrimerEvento.ipynb         ST03L173.SV.EHZ..20160426_120000.mseed
# Proyecto.ipynb             ST03L173.SV.EHZ..20160426_130000.mseed
# Py señales.ipynb           SV.ST03L..EHE.SAC
# README.md                  SV.ST03L..EHN.SAC
# ResumenJuliacon2017.ipynb  SV.ST03L..EHZ.SAC
# ...

# %% [markdown]
# ### Traza Elevación (Z)

# %%
stZ2=read("ST03L173.SV.EHZ*mseed")

# %%
stZ2
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHZ | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHZ | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHZ | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
stZ2.plot()

# %%
stZ2
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHZ | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHZ | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHZ | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
trZ2=stZ2[0].copy()

# %%
trZ2
# Out:
# SV.ST03L..EHZ | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
trZ2.plot()

# %%
trZ2.stats
# Out:
#          network: SV
#          station: ST03L
#         location:
#          channel: EHZ
#        starttime: 2016-04-26T11:00:00.000000Z
#          endtime: 2016-04-26T11:59:59.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 360000
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'record_length': 512, 'encoding': u'STEIM1', 'filesize': 475648, u'dataquality': u'D', 'number_of_records': 929, 'byteorder': u'>'})

# %%
tZ2=trZ2.stats.starttime

# %%
tZ2
# Out:
# 2016-04-26T11:00:00.000000Z

# %%
trZ2.trim(tZ2+(0*60),tZ2+(4*60))
# Out:
# SV.ST03L..EHZ | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:04:00.000000Z | 100.0 Hz, 24001 samples

# %%
trZ2.plot()

# %%
trZ2.write("AZ2SISMO.SAC",format="SAC")

# %%
ls
# Out:
# AE1COMPARACIÓN.SAC         Sismo1E.SAC
# AE1SISMO.SAC               Sismo1N.SAC
# AE2SISMO.SAC               Sismo1Z.SAC
# AN1SISMO.SAC               Sismo2E.SAC
# AN2SISMO.SAC               Sismo2N.SAC
# AZ1SISMO.SAC               Sismo2Z.SAC
# AZ2SISMO.SAC               ST03L173.SV.EHE..20160426_110000.mseed
# E1COMPARACIÓN.SAC          ST03L173.SV.EHE..20160426_120000.mseed
# E1SISMO.SAC                ST03L173.SV.EHE..20160426_130000.mseed
# Juliaexpress.ipynb         ST03L173.SV.EHN..20160426_110000.mseed
# KSISMOS1.ipynb             ST03L173.SV.EHN..20160426_120000.mseed
# KSISMOS2.ipynb             ST03L173.SV.EHN..20160426_130000.mseed
# N1SISMO.SAC                ST03L173.SV.EHZ..20160426_110000.mseed
# PrimerEvento.ipynb         ST03L173.SV.EHZ..20160426_120000.mseed
# Proyecto.ipynb             ST03L173.SV.EHZ..20160426_130000.mseed
# Py señales.ipynb           SV.ST03L..EHE.SAC
# README.md                  SV.ST03L..EHN.SAC
# ResumenJuliacon2017.ipynb  SV.ST03L..EHZ.SAC
# ...

# %% [markdown]
# ## Datos de Verano

# %%
from obspy import read

# %%
ls
# Out:
# Juliaexpress.ipynb         ST03L173.SV.EHE..20160426_110000.mseed
# PrimerEvento.ipynb         ST03L173.SV.EHE..20160426_120000.mseed
# Proyecto.ipynb             ST03L173.SV.EHE..20160426_130000.mseed
# Py señales.ipynb           ST03L173.SV.EHN..20160426_110000.mseed
# README.md                  ST03L173.SV.EHN..20160426_120000.mseed
# ResumenJuliacon2017.ipynb  ST03L173.SV.EHN..20160426_130000.mseed
# SegundoEvento.ipynb        ST03L173.SV.EHZ..20160426_110000.mseed
# SeñalesPy.ipynb            ST03L173.SV.EHZ..20160426_120000.mseed
# Sismo1E.SAC                ST03L173.SV.EHZ..20160426_130000.mseed
# Sismo1N.SAC                SV.ST03L..EHE.SAC
# Sismo1Z.SAC                SV.ST03L..EHN.SAC
# Sismo2E.SAC                SV.ST03L..EHZ.SAC
# Sismo2N.SAC                Untitled.ipynb
# Sismo2Z.SAC                VeranoIntro.ipynb

# %% [markdown]
# ### Traza Este (E)

# %%
stE= read ("ST03L173.SV.EHE*.mseed")

# %%
stE
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHE | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHE | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHE | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
stE.plot()

# %%
stE
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHE | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHE | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHE | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
trE = stE[1].copy()

# %%
trE
# Out:
# SV.ST03L..EHE | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
trE.plot()

# %%
trE.stats
# Out:
#          network: SV
#          station: ST03L
#         location:
#          channel: EHE
#        starttime: 2016-04-26T12:00:00.000000Z
#          endtime: 2016-04-26T12:59:59.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 360000
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'record_length': 512, 'encoding': u'STEIM1', 'filesize': 536064, u'dataquality': u'D', 'number_of_records': 1047, 'byteorder': u'>'})

# %%
tE1 = trE.stats.starttime

# %%
tE1
# Out:
# 2016-04-26T12:00:00.000000Z

# %%
trE.trim(tE1,tE1+(15*60))
# Out:
# SV.ST03L..EHE | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:15:00.000000Z | 100.0 Hz, 90001 samples

# %%
trE
# Out:
# SV.ST03L..EHE | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:15:00.000000Z | 100.0 Hz, 90001 samples

# %%
trE.plot()

# %%
trE.trim(tE1+(2.5*60),tE1+(7.5*60))
# Out:
# SV.ST03L..EHE | 2016-04-26T12:02:30.000000Z - 2016-04-26T12:07:30.000000Z | 100.0 Hz, 30001 samples

# %%
trE.plot()

# %%
trE.trim(tE1+(4*60),tE1+(7*60))
# Out:
# SV.ST03L..EHE | 2016-04-26T12:04:00.000000Z - 2016-04-26T12:07:00.000000Z | 100.0 Hz, 18001 samples

# %%
trE.plot()

# %%
# ?trE.write #Esto es sólo para saber el formato

# %%
trE.write("AE1SISMO.SAC",format="SAC")

# %%
ls
# Out:
# AE1COMPARACIÓN.SAC         Sismo2E.SAC
# AE1SISMO.SAC               Sismo2N.SAC
# AN1SISMO.SAC               Sismo2Z.SAC
# E1COMPARACIÓN.SAC          ST03L173.SV.EHE..20160426_110000.mseed
# E1SISMO.SAC                ST03L173.SV.EHE..20160426_120000.mseed
# Juliaexpress.ipynb         ST03L173.SV.EHE..20160426_130000.mseed
# N1SISMO.SAC                ST03L173.SV.EHN..20160426_110000.mseed
# PrimerEvento.ipynb         ST03L173.SV.EHN..20160426_120000.mseed
# Proyecto.ipynb             ST03L173.SV.EHN..20160426_130000.mseed
# Py señales.ipynb           ST03L173.SV.EHZ..20160426_110000.mseed
# README.md                  ST03L173.SV.EHZ..20160426_120000.mseed
# ResumenJuliacon2017.ipynb  ST03L173.SV.EHZ..20160426_130000.mseed
# SegundoEvento.ipynb        SV.ST03L..EHE.SAC
# SeñalesPy.ipynb            SV.ST03L..EHN.SAC
# Sismo1E.SAC                SV.ST03L..EHZ.SAC
# Sismo1N.SAC                Untitled.ipynb
# Sismo1Z.SAC                VeranoIntro.ipynb

# %% [markdown]
# ### Comparación Traza Este (E):

# %%
stE2=read("ST03L173.SV.EHE*mseed")

# %%
stE2
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHE | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHE | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHE | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
stE2.plot()

# %%
stE2
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHE | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHE | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHE | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
trE2=stE2[1].copy()

# %%
trE2
# Out:
# SV.ST03L..EHE | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
trE2.plot()

# %%
trE2.stats
# Out:
#          network: SV
#          station: ST03L
#         location:
#          channel: EHE
#        starttime: 2016-04-26T12:00:00.000000Z
#          endtime: 2016-04-26T12:59:59.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 360000
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'record_length': 512, 'encoding': u'STEIM1', 'filesize': 536064, u'dataquality': u'D', 'number_of_records': 1047, 'byteorder': u'>'})

# %%
t2E1=trE2.stats.starttime

# %%
t2E1
# Out:
# 2016-04-26T12:00:00.000000Z

# %%
trE2.trim(t2E1+(4*60),t2E1+(7*60))
# Out:
# SV.ST03L..EHE | 2016-04-26T12:04:00.000000Z - 2016-04-26T12:07:00.000000Z | 100.0 Hz, 18001 samples

# %%
trE2.plot()

# %%
trE2.write("AE1COMPARACIÓN.SAC",format="SAC")

# %%
ls
# Out:
# AE1COMPARACIÓN.SAC         Sismo2E.SAC
# AE1SISMO.SAC               Sismo2N.SAC
# AN1SISMO.SAC               Sismo2Z.SAC
# E1COMPARACIÓN.SAC          ST03L173.SV.EHE..20160426_110000.mseed
# E1SISMO.SAC                ST03L173.SV.EHE..20160426_120000.mseed
# Juliaexpress.ipynb         ST03L173.SV.EHE..20160426_130000.mseed
# N1SISMO.SAC                ST03L173.SV.EHN..20160426_110000.mseed
# PrimerEvento.ipynb         ST03L173.SV.EHN..20160426_120000.mseed
# Proyecto.ipynb             ST03L173.SV.EHN..20160426_130000.mseed
# Py señales.ipynb           ST03L173.SV.EHZ..20160426_110000.mseed
# README.md                  ST03L173.SV.EHZ..20160426_120000.mseed
# ResumenJuliacon2017.ipynb  ST03L173.SV.EHZ..20160426_130000.mseed
# SegundoEvento.ipynb        SV.ST03L..EHE.SAC
# SeñalesPy.ipynb            SV.ST03L..EHN.SAC
# Sismo1E.SAC                SV.ST03L..EHZ.SAC
# Sismo1N.SAC                Untitled.ipynb
# Sismo1Z.SAC                VeranoIntro.ipynb

# %% [markdown]
# ### Traza Norte (N)

# %%
stN=read("ST03L173.SV.EHN*mseed")

# %%
stN
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHN | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHN | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHN | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
stN.plot()

# %%
stN
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHN | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHN | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHN | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
trN=stN[1].copy()

# %%
trN
# Out:
# SV.ST03L..EHN | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
trN.plot()

# %%
trN.stats
# Out:
#          network: SV
#          station: ST03L
#         location:
#          channel: EHN
#        starttime: 2016-04-26T12:00:00.000000Z
#          endtime: 2016-04-26T12:59:59.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 360000
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'record_length': 512, 'encoding': u'STEIM1', 'filesize': 547328, u'dataquality': u'D', 'number_of_records': 1069, 'byteorder': u'>'})

# %%
tN1=trN.stats.starttime

# %%
tN1
# Out:
# 2016-04-26T12:00:00.000000Z

# %%
trN.trim(tN1+(4*60),tN1+(7*60))
# Out:
# SV.ST03L..EHN | 2016-04-26T12:04:00.000000Z - 2016-04-26T12:07:00.000000Z | 100.0 Hz, 18001 samples

# %%
trN.plot()

# %%
trN.write("AN1SISMO.SAC",format="SAC")

# %%
ls
# Out:
# AE1COMPARACIÓN.SAC         Sismo2E.SAC
# AE1SISMO.SAC               Sismo2N.SAC
# AN1SISMO.SAC               Sismo2Z.SAC
# E1COMPARACIÓN.SAC          ST03L173.SV.EHE..20160426_110000.mseed
# E1SISMO.SAC                ST03L173.SV.EHE..20160426_120000.mseed
# Juliaexpress.ipynb         ST03L173.SV.EHE..20160426_130000.mseed
# N1SISMO.SAC                ST03L173.SV.EHN..20160426_110000.mseed
# PrimerEvento.ipynb         ST03L173.SV.EHN..20160426_120000.mseed
# Proyecto.ipynb             ST03L173.SV.EHN..20160426_130000.mseed
# Py señales.ipynb           ST03L173.SV.EHZ..20160426_110000.mseed
# README.md                  ST03L173.SV.EHZ..20160426_120000.mseed
# ResumenJuliacon2017.ipynb  ST03L173.SV.EHZ..20160426_130000.mseed
# SegundoEvento.ipynb        SV.ST03L..EHE.SAC
# SeñalesPy.ipynb            SV.ST03L..EHN.SAC
# Sismo1E.SAC                SV.ST03L..EHZ.SAC
# Sismo1N.SAC                Untitled.ipynb
# Sismo1Z.SAC                VeranoIntro.ipynb

# %% [markdown]
# ### Traza Elevación (Z)

# %%
stZ=read("ST03L173.SV.EHZ*mseed")

# %%
stZ
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHZ | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHZ | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHZ | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
stZ.plot()

# %%
stZ
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHZ | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHZ | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHZ | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
trZ=stZ[1].copy()

# %%
trZ
# Out:
# SV.ST03L..EHZ | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
trZ.plot()

# %%
trZ.stats
# Out:
#          network: SV
#          station: ST03L
#         location:
#          channel: EHZ
#        starttime: 2016-04-26T12:00:00.000000Z
#          endtime: 2016-04-26T12:59:59.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 360000
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'record_length': 512, 'encoding': u'STEIM1', 'filesize': 523264, u'dataquality': u'D', 'number_of_records': 1022, 'byteorder': u'>'})

# %%
tZ1=trZ.stats.starttime

# %%
tZ1
# Out:
# 2016-04-26T12:00:00.000000Z

# %%
trZ.trim(tZ1+(4*60),tZ1+(7*60))
# Out:
# SV.ST03L..EHZ | 2016-04-26T12:04:00.000000Z - 2016-04-26T12:07:00.000000Z | 100.0 Hz, 18001 samples

# %%
trZ.plot()

# %%
trZ.write("AZ1SISMO.SAC",format="SAC")

# %%
ls
# Out:
# AE1COMPARACIÓN.SAC         Sismo2E.SAC
# AE1SISMO.SAC               Sismo2N.SAC
# AN1SISMO.SAC               Sismo2Z.SAC
# AZ1SISMO.SAC               ST03L173.SV.EHE..20160426_110000.mseed
# E1COMPARACIÓN.SAC          ST03L173.SV.EHE..20160426_120000.mseed
# E1SISMO.SAC                ST03L173.SV.EHE..20160426_130000.mseed
# Juliaexpress.ipynb         ST03L173.SV.EHN..20160426_110000.mseed
# N1SISMO.SAC                ST03L173.SV.EHN..20160426_120000.mseed
# PrimerEvento.ipynb         ST03L173.SV.EHN..20160426_130000.mseed
# Proyecto.ipynb             ST03L173.SV.EHZ..20160426_110000.mseed
# Py señales.ipynb           ST03L173.SV.EHZ..20160426_120000.mseed
# README.md                  ST03L173.SV.EHZ..20160426_130000.mseed
# ResumenJuliacon2017.ipynb  SV.ST03L..EHE.SAC
# SegundoEvento.ipynb        SV.ST03L..EHN.SAC
# SeñalesPy.ipynb            SV.ST03L..EHZ.SAC
# Sismo1E.SAC                Untitled.ipynb
# Sismo1N.SAC                VeranoIntro.ipynb
# Sismo1Z.SAC
